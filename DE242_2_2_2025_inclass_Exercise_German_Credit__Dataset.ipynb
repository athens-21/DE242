# %% [markdown]
# <a href="https://colab.research.google.com/github/athens-21/DE242/blob/main/DE242_2_2_2025_inclass_Exercise_German_Credit__Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Programmer** Rattanin Kliangmol
#
# **Date** 11 feb 2025

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
statlog_german_credit_data = fetch_ucirepo(id=144)

# data (as pandas dataframes)
df = statlog_german_credit_data.data.original

X = statlog_german_credit_data.data.features
y = statlog_german_credit_data.data.targets

df.head()
# Out:
#   Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0        A11           6        A34        A43        1169        A65
# 1        A12          48        A32        A43        5951        A61
# 2        A14          12        A34        A46        2096        A61
# 3        A11          42        A32        A42        7882        A61
# 4        A11          24        A33        A40        4870        A61
#
#   Attribute7  Attribute8 Attribute9 Attribute10  ...  Attribute12 Attribute13  \
# 0        A75           4        A93        A101  ...         A121          67
# 1        A73           2        A92        A101  ...         A121          22
# 2        A74           2        A93        A101  ...         A121          49
# 3        A74           2        A93        A103  ...         A122          45
# 4        A73           3        A93        A101  ...         A124          53
#
# ...

# %%
X.head()
# Out:
#   Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0        A11           6        A34        A43        1169        A65
# 1        A12          48        A32        A43        5951        A61
# 2        A14          12        A34        A46        2096        A61
# 3        A11          42        A32        A42        7882        A61
# 4        A11          24        A33        A40        4870        A61
#
#   Attribute7  Attribute8 Attribute9 Attribute10  Attribute11 Attribute12  \
# 0        A75           4        A93        A101            4        A121
# 1        A73           2        A92        A101            2        A121
# 2        A74           2        A93        A101            3        A121
# 3        A74           2        A93        A103            4        A122
# 4        A73           3        A93        A101            4        A124
#
#    Attribute13 Attribute14 Attribute15  Attribute16 Attribute17  Attribute18  \
# ...

# %%
y.head()
# Out:
#    class
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2

# %%
statlog_german_credit_data.variables.description
# Out:
# 0                   Status of existing checking account
# 1                                              Duration
# 2                                        Credit history
# 3                                               Purpose
# 4                                         Credit amount
# 5                                 Savings account/bonds
# 6                              Present employment since
# 7     Installment rate in percentage of disposable i...
# 8                               Personal status and sex
# 9                            Other debtors / guarantors
# 10                              Present residence since
# 11                                             Property
# 12                                                  Age
# 13                              Other installment plans
# 14                                              Housing
# 15              Number of existing credits at this bank
# 16                                                  Job
# ...

# %%
df.dtypes
# Out:
# Attribute1     object
# Attribute2      int64
# Attribute3     object
# Attribute4     object
# Attribute5      int64
# Attribute6     object
# Attribute7     object
# Attribute8      int64
# Attribute9     object
# Attribute10    object
# Attribute11     int64
# Attribute12    object
# Attribute13     int64
# Attribute14    object
# Attribute15    object
# Attribute16     int64
# Attribute17    object
# Attribute18     int64
# Attribute19    object
# Attribute20    object
# class           int64
# dtype: object

# %%
col_names = ['chk_account_status', 'duration',
'credit_history', 'purpose', 'credit_amount', 'saving_account_balance',
'current_employment_duration', 'installment_rate', 'marital_status',
'type_of_other_debtors', 'current_residence_duration',
'property', 'age', 'other_installment_plan',
'housing', 'num_of_existing_credits', 'job', 'num_of_liable_people', 'telephone',
'foreign_worker', 'target']

# %%
df.columns = col_names

# %%
df.head()
# Out:
#   chk_account_status  duration credit_history purpose  credit_amount  \
# 0                A11         6            A34     A43           1169
# 1                A12        48            A32     A43           5951
# 2                A14        12            A34     A46           2096
# 3                A11        42            A32     A42           7882
# 4                A11        24            A33     A40           4870
#
#   saving_account_balance current_employment_duration  installment_rate  \
# 0                    A65                         A75                 4
# 1                    A61                         A73                 2
# 2                    A61                         A74                 2
# 3                    A61                         A74                 2
# 4                    A61                         A73                 3
#
#   marital_status type_of_other_debtors  ...  property age  \
# 0            A93                  A101  ...      A121  67
# ...

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#        chk_account_status credit_history purpose saving_account_balance  \
# count                1000           1000    1000                   1000
# unique                  4              5      10                      5
# top                   A14            A32     A43                    A61
# freq                  394            530     280                    603
#
#        current_employment_duration marital_status type_of_other_debtors  \
# count                         1000           1000                  1000
# unique                           5              4                     3
# top                            A73            A93                  A101
# freq                           339            548                   907
#
#        property other_installment_plan housing   job telephone foreign_worker
# count      1000                   1000    1000  1000      1000           1000
# unique        4                      3       3     4         2              2
# ...

# %%
df.select_dtypes(exclude=['object']).describe()
# Out:
#           duration  credit_amount  installment_rate  \
# count  1000.000000    1000.000000       1000.000000
# mean     20.903000    3271.258000          2.973000
# std      12.058814    2822.736876          1.118715
# min       4.000000     250.000000          1.000000
# 25%      12.000000    1365.500000          2.000000
# 50%      18.000000    2319.500000          3.000000
# 75%      24.000000    3972.250000          4.000000
# max      72.000000   18424.000000          4.000000
#
#        current_residence_duration          age  num_of_existing_credits  \
# count                 1000.000000  1000.000000              1000.000000
# mean                     2.845000    35.546000                 1.407000
# std                      1.103718    11.375469                 0.577654
# min                      1.000000    19.000000                 1.000000
# 25%                      2.000000    27.000000                 1.000000
# ...

# %%
df['target'].value_counts(dropna=False)
# Out:
# target
# 1    700
# 2    300
# Name: count, dtype: int64

# %%
df['target'] = df['target'].replace({2:0})
df.head()
# Out:
#   chk_account_status  duration credit_history purpose  credit_amount  \
# 0                A11         6            A34     A43           1169
# 1                A12        48            A32     A43           5951
# 2                A14        12            A34     A46           2096
# 3                A11        42            A32     A42           7882
# 4                A11        24            A33     A40           4870
#
#   saving_account_balance current_employment_duration  installment_rate  \
# 0                    A65                         A75                 4
# 1                    A61                         A73                 2
# 2                    A61                         A74                 2
# 3                    A61                         A74                 2
# 4                    A61                         A73                 3
#
#   marital_status type_of_other_debtors  ...  property age  \
# 0            A93                  A101  ...      A121  67
# ...

# %%
cp_df = df.copy()
cp_df.head()
# Out:
#   chk_account_status  duration credit_history purpose  credit_amount  \
# 0                A11         6            A34     A43           1169
# 1                A12        48            A32     A43           5951
# 2                A14        12            A34     A46           2096
# 3                A11        42            A32     A42           7882
# 4                A11        24            A33     A40           4870
#
#   saving_account_balance current_employment_duration  installment_rate  \
# 0                    A65                         A75                 4
# 1                    A61                         A73                 2
# 2                    A61                         A74                 2
# 3                    A61                         A74                 2
# 4                    A61                         A73                 3
#
#   marital_status type_of_other_debtors  ...  property age  \
# 0            A93                  A101  ...      A121  67
# ...

# %% [markdown]
# **Prepare the data**

# %%
cp_df.isnull().any(axis=0)
# Out:
# chk_account_status             False
# duration                       False
# credit_history                 False
# purpose                        False
# credit_amount                  False
# saving_account_balance         False
# current_employment_duration    False
# installment_rate               False
# marital_status                 False
# type_of_other_debtors          False
# current_residence_duration     False
# property                       False
# age                            False
# other_installment_plan         False
# housing                        False
# num_of_existing_credits        False
# job                            False
# num_of_liable_people           False
# telephone                      False
# foreign_worker                 False
# target                         False
# dtype: bool

# %% [markdown]
# Eliminating outliers

# %%
numeric_cols = cp_df.select_dtypes(exclude=['object']).columns.tolist()[0:-1]
numeric_cols
# Out:
# ['duration',
#  'credit_amount',
#  'installment_rate',
#  'current_residence_duration',
#  'age',
#  'num_of_existing_credits',
#  'num_of_liable_people']

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(figsize=(18, 10), nrows=2, ncols=4, squeeze=0)
i = 0
for ax, col in zip(axes.reshape(-1), numeric_cols):
  ax.boxplot(df[col], tick_labels=[col], sym='k')
plt.tight_layout()

# %%
q1 = cp_df['num_of_existing_credits'].quantile(0.25)
q2 = cp_df['num_of_existing_credits'].quantile(0.50)
q3 = cp_df['num_of_existing_credits'].quantile(0.75)

iqr = q3-q1

lower_bound = q1-(1.5*iqr)
upper_bound = q3+(1.5*iqr)

print('q1 = {}'.format(q1))
print('q2 = {}'.format(q2))
print('q3 = {}'.format(q3))
print('lqr = {}'.format(iqr))
print('lower bound = {}'.format(lower_bound))
print('upper bound = {}'.format(upper_bound))
# Out:
# q1 = 1.0
# q2 = 1.0
# q3 = 2.0
# lqr = 1.0
# lower bound = -0.5
# upper bound = 3.5

# %%
outlier_row_indice = cp_df[(cp_df['num_of_existing_credits']<lower_bound) | (df['num_of_existing_credits']>upper_bound)].index
print('number of outliers = {}'.format(len(outlier_row_indice)))
print('indice of outliers = ', outlier_row_indice.tolist())
# Out:
# number of outliers = 6
# indice of outliers =  [65, 197, 590, 653, 807, 890]

# %%
cp_df['num_of_existing_credits'].iloc[65:66]
# Out:
# 65    4
# Name: num_of_existing_credits, dtype: int64

# %%
cp_df['num_of_existing_credits'].iloc[590:591]
# Out:
# 590    4
# Name: num_of_existing_credits, dtype: int64

# %%
cp_df.drop(outlier_row_indice, inplace=True)
cp_df.shape
# Out:
# (994, 21)

# %%
cp_df[['age','credit_amount']].head()
# Out:
#    age  credit_amount
# 0   67           1169
# 1   22           5951
# 2   49           2096
# 3   45           7882
# 4   53           4870

# %%
X = cp_df.iloc[:, 0:-1]
y = cp_df.iloc[:, -1]

# %%
X.head()
# Out:
#   chk_account_status  duration credit_history purpose  credit_amount  \
# 0                A11         6            A34     A43           1169
# 1                A12        48            A32     A43           5951
# 2                A14        12            A34     A46           2096
# 3                A11        42            A32     A42           7882
# 4                A11        24            A33     A40           4870
#
#   saving_account_balance current_employment_duration  installment_rate  \
# 0                    A65                         A75                 4
# 1                    A61                         A73                 2
# 2                    A61                         A74                 2
# 3                    A61                         A74                 2
# 4                    A61                         A73                 3
#
#   marital_status type_of_other_debtors  current_residence_duration property  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: target, dtype: int64

# %%
numeric_cols = X.select_dtypes(exclude=['object']).columns.tolist()
numeric_cols
# Out:
# ['duration',
#  'credit_amount',
#  'installment_rate',
#  'current_residence_duration',
#  'age',
#  'num_of_existing_credits',
#  'num_of_liable_people']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X[numeric_cols])
X[numeric_cols] = scaler.transform(X[numeric_cols])
X[numeric_cols].tail()
# Out:
#      duration  credit_amount  installment_rate  current_residence_duration  \
# 995 -0.737772      -0.544713          0.027877                    1.052146
# 996  0.753947       0.207013          0.921753                    1.052146
# 997 -0.737772      -0.875033          0.921753                    1.052146
# 998  1.997046      -0.506081          0.921753                    1.052146
# 999  1.997046       0.461842          0.027877                    1.052146
#
#           age  num_of_existing_credits  num_of_liable_people
# 995 -0.395089                -0.721101             -0.426528
# 996  0.399352                -0.721101             -0.426528
# 997  0.222809                -0.721101             -0.426528
# 998 -1.101259                -0.721101             -0.426528
# 999 -0.748174                -0.721101             -0.426528

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=9999)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (695, 20) (695,)
# (299, 20) (299,)

# %%
categorical_cols = X.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['chk_account_status', 'credit_history', 'purpose',
#        'saving_account_balance', 'current_employment_duration',
#        'marital_status', 'type_of_other_debtors', 'property',
#        'other_installment_plan', 'housing', 'job', 'telephone',
#        'foreign_worker'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
oh_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
transformer = make_column_transformer((oh_encoder, categorical_cols))

# %%
#https://www.kaggle.com/code/marcinrutecki/one-hot-encoding-everything-you-need-to-know
import pandas as pd
import numpy as np
# Fitting
# Transforming
transformed = transformer.fit_transform(X_train)
# Transformating back
transformed_df = pd.DataFrame(transformed, columns=transformer.get_feature_names_out())
# One-hot encoding removed an index. Let's put it back:
transformed_df.index = X_train.index
# Joining tables
X_train = pd.concat([X_train, transformed_df], axis=1)
# Dropping old categorical columns
X_train.drop(categorical_cols, axis=1, inplace=True)
# CHecking result
X_train.head()
# Out:
#      duration  credit_amount  installment_rate  current_residence_duration  \
# 629 -0.986392       0.198153         -1.759874                    1.052146
# 111 -0.489153      -1.021055          0.921753                    1.052146
# 784 -0.074786       1.132406         -1.759874                    1.052146
# 499 -1.235012      -0.691089         -0.865998                    1.052146
# 636  0.256707      -0.672305          0.921753                   -1.666657
#
#           age  num_of_existing_credits  num_of_liable_people  \
# 629  2.517861                -0.721101             -0.426528
# 111 -1.101259                -0.721101             -0.426528
# 784  2.164776                -0.721101             -0.426528
# 499 -0.659903                 1.121507              2.344511
# 636 -0.659903                -0.721101             -0.426528
#
#      onehotencoder__chk_account_status_A11  \
# 629                                    0.0
# 111                                    0.0
# ...

# %%
#https://www.kaggle.com/code/marcinrutecki/one-hot-encoding-everything-you-need-to-know
# Transforming
transformed = transformer.transform(X_test)
# Transformating back
transformed_df = pd.DataFrame(transformed, columns=transformer.get_feature_names_out())
# One-hot encoding removed an index. Let's put it back:
transformed_df.index = X_test.index
# Joining tables
X_test = pd.concat([X_test, transformed_df], axis=1)
# Dropping old categorical columns
X_test.drop(categorical_cols, axis=1, inplace=True)
# Checking resul
X_test.shape
# Out:
# (299, 61)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(max_depth=8, min_samples_leaf=3, min_samples_split=3, n_estimators=5000, random_state=13)
rf.fit(X_train, y_train.values.ravel())
# select a specified number of features
fs = SelectFromModel(rf, max_features=20)
# learn relationship from training data
fs.fit(X_train, y_train)
#fs.fit(X_train, y_train.values.ravel()) #Use this line if getting a warning.
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data

# %%
X_train_fs[0:1]
# Out:
# array([[-0.98639231,  0.19815258, -1.7598743 ,  1.0521457 ,  2.51786061,
#          0.        ,  0.        ,  1.        ,  0.        ,  0.        ,
#          0.        ,  1.        ,  1.        ]])

# %%
feature_importance = pd.Series(data=rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)
print(feature_importance)
# Out:
# credit_amount                            0.108867
# onehotencoder__chk_account_status_A14    0.098645
# duration                                 0.085183
# age                                      0.067718
# onehotencoder__chk_account_status_A11    0.065471
#                                            ...
# onehotencoder__purpose_A44               0.000975
# onehotencoder__purpose_A410              0.000784
# onehotencoder__purpose_A45               0.000483
# onehotencoder__job_A171                  0.000362
# onehotencoder__purpose_A48               0.000025
# Length: 61, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(17,13))
plt.title("Feature importance")
#https://www.geeksforgeeks.org/seaborn-barplot-method-in-python/
ax = sns.barplot(y=feature_importance.index, x=feature_importance.values, palette="Blues", orient='h')
# Out:
# <ipython-input-129-380082bd8f35>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=feature_importance.index, x=feature_importance.values, palette="Blues", orient='h')

# %%
#https://machinelearningmastery.com/calculate-feature-importance-with-python/
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(max_depth=8, min_samples_leaf=3, min_samples_split=3, n_estimators=5000, random_state=13)
# select a specified number of features
fs = SelectFromModel(rf, max_features=20)
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clf_rf = RandomForestClassifier(n_estimators = 1000, random_state=13)
clf_rf.fit(X_train_fs, y_train.values.ravel())
predictions = clf_rf.predict(X_test_fs)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)
print("Performance:")
print(" - accuracy = " + str(accuracy))
print(" - precision = " + str(precision))
print(" - recall = " + str(recall))
print(" - f1 = " + str(f1))
# Out:
# Performance:
#  - accuracy = 0.7658862876254181
#  - precision = 0.7983539094650206
#  - recall = 0.9023255813953488
#  - f1 = 0.8471615720524017

# %%
#Random forest (no manual feature engineering)
clf_rf = RandomForestClassifier(max_depth=8, min_samples_leaf=3, min_samples_split=3, n_estimators=5000, random_state=13)
clf_rf.fit(X_train, y_train.values.ravel())
predictions = clf_rf.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)
print("Performance:")
print(" - accuracy = " + str(accuracy))
print(" - precision = " + str(precision))
print(" - recall = " + str(recall))
print(" - f1 = " + str(f1))

#accuracy = Number of correct predict prediction/total number of rows inthe test_set
# Out:
# Performance:
#  - accuracy = 0.7725752508361204
#  - precision = 0.7859922178988327
#  - recall = 0.9395348837209302
#  - f1 = 0.8559322033898306

# %%
clf_svm = svm.SVC(kernel='linear', tol=0.01)#Linear separable
#clf_svm = svm.SVC(kernel='rbf', tol=0.01)#Non-linear separable
clf_svm.fit(X_train_fs,y_train.values.ravel())
predictions = clf_svm.predict(X_test_fs)

print("Performance:")
print(" - accuracy = " + str(accuracy))
print(" - precision = " + str(precision))
print(" - recall = " + str(recall))
print(" - f1 = " + str(f1))
# Out:
# Performance:
#  - accuracy = 0.7725752508361204
#  - precision = 0.7859922178988327
#  - recall = 0.9395348837209302
#  - f1 = 0.8559322033898306

# %% [markdown]
# Apply the knowledge
# Suppose that the first two rows ar
