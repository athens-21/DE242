# %% [markdown]
# <a href="https://colab.research.google.com/github/athens-21/DE242/blob/main/Numerical_data_science_Credit_scoring_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
'Title':['Ms.', 'Mr.', 'Mr.', None, 'Miss'],
'Age': [25, 31, 22, 25, 27],
'Gender': ['F', 'M', 'F' , 'M', 'F'],
'Salary': [50000, 25000 , 30000, 40000, 60000]}
df = pd.DataFrame(data)
df
# Out:
#       Name Title  Age Gender  Salary
# 0    Alice   Ms.   25      F   50000
# 1      Bob   Mr.   31      M   25000
# 2  Charlie   Mr.   22      F   30000
# 3    David  None   25      M   40000
# 4      Eva  Miss   27      F   60000

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
'Age': [25, 31, 22, None, 27],
'Gender': ['F', 'M', None, 'M', 'F'],
'Salary': [50000, None, 30000, 40000, 60000],
'IsStudent':[True, False, None, False, False]}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary IsStudent
# 0    Alice  25.0      F  50000.0      True
# 1      Bob  31.0      M      NaN     False
# 2  Charlie  22.0   None  30000.0      None
# 3    David   NaN      M  40000.0     False
# 4      Eva  27.0      F  60000.0     False

# %%
df.dtypes
# Out:
# Name          object
# Age          float64
# Gender        object
# Salary       float64
# IsStudent     object
# dtype: object

# %%
import os
import numpy as np

df = pd.read_csv('name.txt')
df
# Out:
#       name   age state  point  other
# 0    Alice    24    NY    NaN    NaN
# 1     none   NaN   NaN    NaN    NaN
# 2  Charlie  Null    CA    NaN    NaN
# 3     Dave    68    TX   70.0    NaN
# 4    Ellen   NaN    CA   88.0    NaN
# 5    Frank    30   NaN    NaN    NaN

# %%
df.isnull()
# Out:
#     name    age  state  point  other
# 0  False  False  False   True   True
# 1  False   True   True   True   True
# 2  False  False  False   True   True
# 3  False  False  False  False   True
# 4  False   True  False  False   True
# 5  False  False   True   True   True

# %%
df.isnull().any()
# Out:
# name     False
# age       True
# state     True
# point     True
# other     True
# dtype: bool

# %% [markdown]
# Find row(s) that contain specific values, ‘Null’.

# %%
df[df['age'] == 'Null']
# Out:
#       name   age state  point  other
# 2  Charlie  Null    CA    NaN    NaN

# %% [markdown]
# Drop specific row(s).

# %%
df
# Out:
#       name   age state  point  other
# 0    Alice    24    NY    NaN    NaN
# 1     none   NaN   NaN    NaN    NaN
# 2  Charlie  Null    CA    NaN    NaN
# 3     Dave    68    TX   70.0    NaN
# 4    Ellen   NaN    CA   88.0    NaN
# 5    Frank    30   NaN    NaN    NaN

# %%
none_row_indices = df.loc[df['age'].isnull()].index.to_list()
none_row_indices
# Out:
# [1, 4]

# %%
df1 = df.drop(none_row_indices)

# %%
df1
# Out:
#       name   age state  point  other
# 0    Alice    24    NY    NaN    NaN
# 2  Charlie  Null    CA    NaN    NaN
# 3     Dave    68    TX   70.0    NaN
# 5    Frank    30   NaN    NaN    NaN

# %%
df1 = df1.reset_index(drop=False)
df1
# Out:
#    index     name   age state  point  other
# 0      0    Alice    24    NY    NaN    NaN
# 1      2  Charlie  Null    CA    NaN    NaN
# 2      3     Dave    68    TX   70.0    NaN
# 3      5    Frank    30   NaN    NaN    NaN

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#    index     name   age state  point  other
# 0      0    Alice    24    NY    NaN    NaN
# 1      2  Charlie  Null    CA    NaN    NaN
# 2      3     Dave    68    TX   70.0    NaN
# 3      5    Frank    30   NaN    NaN    NaN

# %%
df1['age'].fillna(0)
# Out:
# 0      24
# 1    Null
# 2      68
# 3      30
# Name: age, dtype: object
